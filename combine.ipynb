# %% [markdown]
# # Combine modern with historic data

# %%
import pandas as pd
import numpy as np

# %%
# Digitized from pdfs here:
# https://www.ncsl.org/research/about-state-legislatures/partisan-composition.aspx
modern = pd.read_csv('./data/outputs/state_legislative_control_2009_2021.csv')
modern
# Out:
#              state  year  senate_total  senate_dem  senate_rep  senate_other  \
# 0          Alabama  2009            35          19          13             0
# 1           Alaska  2009            20          10          10             0
# 2          Arizona  2009            30          12          18             0
# 3         Arkansas  2009            35          27           8             0
# 4       California  2009            40          26          14             0
# ..             ...   ...           ...         ...         ...           ...
# 645       Virginia  2021            40          21          18             0
# 646     Washington  2021            49          29          20             0
# 647  West Virginia  2021            34          11          23             0
# 648      Wisconsin  2021            33          12          20             0
# 649        Wyoming  2021            30           2          28             0
#
#      house_total  house_dem  house_rep  house_other
# 0            105         62         43            0
# 1             40         18         22            0
# 2             60         25         35            0
# 3            100         71         28            1
# 4             80         51         29            0
# ..           ...        ...        ...          ...
# 645          100         55         45            0
# 646           98         57         41            0
# 647          100         23         77            0
# 648           99         38         60            0
# 649           60          7         51            2
#
# [650 rows x 10 columns]

# %%
# Should be available through 2010/2011
# https://dataverse.harvard.edu/dataset.xhtml?persistentId=hdl:1902.1/20403
historic = pd.read_csv('./data/klarner/Partisan_Balance_For_Use2011_06_09b.csv')
select_cols = [
    'year', 'state',  'sen_dem_in_sess', 'sen_rep_in_sess',
     'sen_ind_in_sess', 'sen_tot_in_sess','hs_dem_in_sess',
     'hs_rep_in_sess', 'hs_ind_in_sess','hs_tot_in_sess'
]
renames = [
    'year', 'state', 'senate_dem', 'senate_rep',
    'senate_other', 'senate_total', 'house_dem',
    'house_rep', 'house_other', 'house_total'
]
historic = historic[select_cols]
# int_cols = [i for i in select_cols if i != 'state']
# historic[int_cols] = historic[int_cols].astype('int')
historic = historic.rename(columns=dict(zip(select_cols, renames)))
# Remove overlap with modern data above
historic = historic.query('year < 2009')
historic
# Out:
#       year      state  senate_dem  senate_rep  senate_other  senate_total  \
# 0     1939    Alabama        35.0         0.0           0.0          35.0
# 1     1940    Alabama        35.0         0.0           0.0          35.0
# 2     1941    Alabama        35.0         0.0           0.0          35.0
# 3     1942    Alabama        35.0         0.0           0.0          35.0
# 4     1943    Alabama        35.0         0.0           0.0          35.0
# ...    ...        ...         ...         ...           ...           ...
# 4085  1935  Wisconsin         NaN         NaN           NaN           NaN
# 4086  1936  Wisconsin         NaN         NaN           NaN           NaN
# 4092  1934    Wyoming         NaN         NaN           NaN           NaN
# 4093  1935    Wyoming         NaN         NaN           NaN           NaN
# 4094  1936    Wyoming         NaN         NaN           NaN           NaN
#
#       house_dem  house_rep  house_other  house_total
# 0         105.0        1.0          0.0        106.0
# 1         105.0        1.0          0.0        106.0
# 2         105.0        1.0          0.0        106.0
# 3         105.0        1.0          0.0        106.0
# 4         105.0        1.0          0.0        106.0
# ...         ...        ...          ...          ...
# 4085        NaN        NaN          NaN          NaN
# 4086        NaN        NaN          NaN          NaN
# 4092        NaN        NaN          NaN          NaN
# 4093        NaN        NaN          NaN          NaN
# 4094        NaN        NaN          NaN          NaN
#
# [3750 rows x 10 columns]

# %%
# There are some missing records, but keep null values for now
# Note that many of the missing values are from Nebraska,
# which is unicameral and technically nonpartisan.
missing = historic[historic.isna().any(axis=1)]
print('Missing state annual records: ', len(missing))
print('Covering: ', len(missing['year'].drop_duplicates()), 'years')
missing.head(10)
# Out:
# Missing state annual records:  259
# Covering:  75 years
#       year      state  senate_dem  senate_rep  senate_other  senate_total  \
# 2681  1937  Minnesota         NaN         NaN           NaN           NaN
# 2682  1938  Minnesota         NaN         NaN           NaN           NaN
# 3592  1934    Alabama         NaN         NaN           NaN           NaN
# 3593  1935    Alabama         NaN         NaN           NaN           NaN
# 3594  1936    Alabama         NaN         NaN           NaN           NaN
# 3595  1937    Alabama         NaN         NaN           NaN           NaN
# 3596  1938    Alabama         NaN         NaN           NaN           NaN
# 3602  1934     Alaska         NaN         NaN           NaN           NaN
# 3603  1935     Alaska         NaN         NaN           NaN           NaN
# 3604  1936     Alaska         NaN         NaN           NaN           NaN
#
#       house_dem  house_rep  house_other  house_total
# 2681        NaN        NaN          NaN          NaN
# 2682        NaN        NaN          NaN          NaN
# 3592        NaN        NaN          NaN          NaN
# 3593        NaN        NaN          NaN          NaN
# 3594        NaN        NaN          NaN          NaN
# 3595        NaN        NaN          NaN          NaN
# 3596        NaN        NaN          NaN          NaN
# 3602        NaN        NaN          NaN          NaN
# 3603        NaN        NaN          NaN          NaN
# 3604        NaN        NaN          NaN          NaN

# %% [markdown]
# # Combine

# %%
all_records = pd.concat([modern, historic])
all_records = all_records.sort_values(by=['state', 'year'], ascending=True)
all_records.to_csv('./data/outputs/state_legislative_control_1934_2021.csv', index=False)
all_records
# Out:
#         state  year  senate_total  senate_dem  senate_rep  senate_other  \
# 3592  Alabama  1934           NaN         NaN         NaN           NaN
# 3593  Alabama  1935           NaN         NaN         NaN           NaN
# 3594  Alabama  1936           NaN         NaN         NaN           NaN
# 3595  Alabama  1937           NaN         NaN         NaN           NaN
# 3596  Alabama  1938           NaN         NaN         NaN           NaN
# ...       ...   ...           ...         ...         ...           ...
# 449   Wyoming  2017          30.0         3.0        27.0           0.0
# 499   Wyoming  2018          30.0         3.0        27.0           0.0
# 549   Wyoming  2019          30.0         3.0        27.0           0.0
# 599   Wyoming  2020          30.0         3.0        27.0           0.0
# 649   Wyoming  2021          30.0         2.0        28.0           0.0
#
#       house_total  house_dem  house_rep  house_other
# 3592          NaN        NaN        NaN          NaN
# 3593          NaN        NaN        NaN          NaN
# 3594          NaN        NaN        NaN          NaN
# 3595          NaN        NaN        NaN          NaN
# 3596          NaN        NaN        NaN          NaN
# ...           ...        ...        ...          ...
# 449          60.0        9.0       51.0          0.0
# 499          60.0        9.0       51.0          0.0
# 549          60.0        9.0       50.0          1.0
# 599          60.0        9.0       50.0          1.0
# 649          60.0        7.0       51.0          2.0
#
# [4400 rows x 10 columns]
